# %% [markdown]
# # Athena for Montgomery audit

# %%
# we either import locally (after the repo was cloned)
# or we first clone it and then use it (e.g., when run in Google Colab)
shell = get_ipython().__class__.__name__ 

if shell == 'Shell':
    # imports when launched in e.g., Google Colab
    # !git clone https://github.com/filipzz/athena.git r2b2
    from r2b2.code.athena.athena import AthenaAudit
    from r2b2.code.athena.contest import Contest
    from r2b2.code.athena.audit import Audit
else: # shell ==  'ZMQInteractiveShell' or shell == 'TerminalInteractiveShell'
    # local imports if you run it with e.g., Jupyter
    from athena.athena import AthenaAudit
    from athena.contest import Contest
    from athena.audit import Audit

import pandas as pd
import json
from IPython.core.display import display, HTML

# %%
risk_limit = 0.1

# %%
# Results, based on data at https://r7j7u2j8.rocketcdn.me/wp-content/uploads/2020/05/03172020es-Official-Final-With-Write-ins.pdf
# Or URL
results_file = "athena/test_data/2020_montgomery-0511-formatted.json"

# %%
results = json.load(open(results_file, 'r'))

# %%
htmlout = ""
for contest in results['contests']:
    htmlout += f"<H1>{contest}</H1>\n"
    w = Audit("athena", risk_limit)

    w.read_election_results(results_file)

    w.load_contest(contest)
    print(f'{w.predict_round_sizes([.7, .8, .9])} round sizes for {contest}')

    htmlout += w.show_election_results().render()
# Out:
# [[0.7, 21], [0.8, 25], [0.9, 29]] round sizes for d_president
# [[0.7, 44], [0.8, 62], [0.9, 80]] round sizes for d_congress
# [[0.7, 35], [0.8, 41], [0.9, 58]] round sizes for d_senator
# [[0.7, 68], [0.8, 72], [0.9, 101]] round sizes for d_cc_1_2_2021
# [[0.7, 24], [0.8, 24], [0.9, 38]] round sizes for d_cc_1_3_2021
# [[0.7, 19], [0.8, 20], [0.9, 24]] round sizes for r_10th
# [[0.7, 77], [0.8, 83], [0.9, 115]] round sizes for r_senator
# [[0.7, 156], [0.8, 171], [0.9, 257]] round sizes for r_42nd
# [[0.7, 144], [0.8, 167], [0.9, 228]] round sizes for r_cc_1_2_2021

# %%
display(HTML(htmlout))
# Out:
# <H1>d_president</H1>
# <style  type="text/css" >
#     #T_10cb36bc_9a4b_11ea_a579_e09d31573688row1_col0 {
#             color:  green;
#         }    #T_10cb36bc_9a4b_11ea_a579_e09d31573688row1_col1 {
#             color:  green;
#         }</style><table id="T_10cb36bc_9a4b_11ea_a579_e09d31573688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Candidates</th>        <th class="col_heading level0 col1" >Results</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row0_col0" class="data row0 col0" >Bennet</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row0_col1" class="data row0 col1" >51</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row1_col0" class="data row1 col0" >Biden</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row1_col1" class="data row1 col1" >29011</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row2_col0" class="data row2 col0" >Bloomberg</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row2_col1" class="data row2 col1" >702</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row3_col0" class="data row3 col0" >Buttigieg</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row3_col1" class="data row3 col1" >525</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row4_col0" class="data row4 col0" >Gabbard</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row4_col1" class="data row4 col1" >137</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row5_col0" class="data row5 col0" >Klobuchar</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row5_col1" class="data row5 col1" >406</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row6_col0" class="data row6 col0" >Patrick</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row6_col1" class="data row6 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row7_col0" class="data row7 col0" >Sanders</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row7_col1" class="data row7 col1" >5713</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row8_col0" class="data row8 col0" >Steyer</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row8_col1" class="data row8 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row9_col0" class="data row9 col0" >Warren</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row9_col1" class="data row9 col1" >1118</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bc_9a4b_11ea_a579_e09d31573688level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row10_col0" class="data row10 col0" >Write_Ins</td>
#                         <td id="T_10cb36bc_9a4b_11ea_a579_e09d31573688row10_col1" class="data row10 col1" >122</td>
#             </tr>
#     </tbody></table><H1>d_congress</H1>
# <style  type="text/css" >
#     #T_10cb36bd_9a4b_11ea_a579_e09d31573688row1_col0 {
#             color:  green;
#         }    #T_10cb36bd_9a4b_11ea_a579_e09d31573688row1_col1 {
#             color:  green;
#         }</style><table id="T_10cb36bd_9a4b_11ea_a579_e09d31573688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Candidates</th>        <th class="col_heading level0 col1" >Results</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10cb36bd_9a4b_11ea_a579_e09d31573688level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_10cb36bd_9a4b_11ea_a579_e09d31573688row0_col0" class="data row0 col0" >Moyer</td>
#                         <td id="T_10cb36bd_9a4b_11ea_a579_e09d31573688row0_col1" class="data row0 col1" >10130</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36bd_9a4b_11ea_a579_e09d31573688level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_10cb36bd_9a4b_11ea_a579_e09d31573688row1_col0" class="data row1 col0" >Tims</td>
#                         <td id="T_10cb36bd_9a4b_11ea_a579_e09d31573688row1_col1" class="data row1 col1" >25047</td>
#             </tr>
#     </tbody></table><H1>d_senator</H1>
# <style  type="text/css" >
#     #T_10cb36be_9a4b_11ea_a579_e09d31573688row1_col0 {
#             color:  green;
#         }    #T_10cb36be_9a4b_11ea_a579_e09d31573688row1_col1 {
#             color:  green;
#         }</style><table id="T_10cb36be_9a4b_11ea_a579_e09d31573688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Candidates</th>        <th class="col_heading level0 col1" >Results</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10cb36be_9a4b_11ea_a579_e09d31573688level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_10cb36be_9a4b_11ea_a579_e09d31573688row0_col0" class="data row0 col0" >Fogel</td>
#                         <td id="T_10cb36be_9a4b_11ea_a579_e09d31573688row0_col1" class="data row0 col1" >16867</td>
#             </tr>
#             <tr>
#                         <th id="T_10cb36be_9a4b_11ea_a579_e09d31573688level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_10cb36be_9a4b_11ea_a579_e09d31573688row1_col0" class="data row1 col0" >Griggs</td>
#                         <td id="T_10cb36be_9a4b_11ea_a579_e09d31573688row1_col1" class="data row1 col1" >3643</td>
#             </tr>
#     </tbody></table><H1>d_cc_1_2_2021</H1>
# <style  type="text/css" >
#     #T_10cb36bf_9a4b_11ea_a579_e09d31573688row1_col0 {
#             color:  green;
#         }    #T_10cb36bf_9a4b_11ea_a579_e09d31573688row1_col1 {
#             color:  green;
#         }</style><table id="T_10cb36bf_9a4b_11ea_a579_e09d31573688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Candidates</th>        <th class="col_heading level0 col1" >Results</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10cb36bf_9a4b_11ea_a579_e09d31573688level0_row0" class="row_heading level0
